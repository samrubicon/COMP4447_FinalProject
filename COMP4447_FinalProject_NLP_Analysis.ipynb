# %%
import pandas as pd
# %matplotlib inline
import numpy as np
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
import contractions
import string

# %%
def clean_text(row):
    all_lyrics_text=row
    
    #Tokenization
    token_all_text=nltk.word_tokenize(all_lyrics_text)
    final_token_text = [word for word in token_all_text if word.isalpha()]
    
    #Expand contractions
    text_no_contract=[contractions.fix(word) for word in final_token_text]
    
    #Remove stop words
    text_no_stp_contract=[word for word in text_no_contract if word.lower() not in stopwords]    
    
    #Lemmatization
    #no_stop_contract_lemma=[]
    #for word in text_no_stp_contract:
        #tag=nltk.pos_tag(word.split(" "))[0][1]
        #pos=get_pos_arg(tag)
        #no_stop_contract_lemma.append(wnetl.lemmatize(word,pos))

    lyrics_text="".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in text_no_stp_contract]).strip()
    return lyrics_text

# %%
scrape_df = pd.read_csv("scrape_3/scrape_data_Aug-20-2021_013514.csv", usecols=np.r_[1:16], low_memory=False, encoding='utf-8', dtype={'Release Genre': str})
scrape_df.index = [x for x in range(1, len(scrape_df.values)+1)]
scrape_df.index.name = 'id'
scrape_df = scrape_df.drop_duplicates(subset = ["Release URL"])
scrape_df.dropna(inplace=True)

scrape_df

#cell_regex=nltk.RegexpTokenizer(pattern=r'\w+', gaps=False)
#cell_regex=nltk.RegexpTokenizer("[\\w']+|[^\\w\\s]+")
cell_regex=nltk.RegexpTokenizer("[\s+]+", gaps=True)
scrape_df['Lyrics Tokens'] = scrape_df['All Lyrics'].apply(cell_regex.tokenize)

#scrape_df= scrape_df.assign(Lyrics_Tokens='')
#for index, row in scrape_df.iterrows():
    #scrape_df.at[index, 'Lyrics Tokens']= clean_text(scrape_df.at[index,'All Lyrics'])
    
scrape_df
# Out:
#      Release Genre Release Sub-Genre Search Format  Search Week  \
# id
# 2              all               all           all    this week
# 6              all               all           all    this week
# 14             all               all           all    this week
# 23             all               all           all    this week
# 25             all               all           all    this week
# ...            ...               ...           ...          ...
# 5576        reggae               all           all  3 weeks ago
# 5583        reggae               all           all  3 weeks ago
# 5599        reggae               all           all  6 weeks ago
# 5606        reggae               all           all  6 weeks ago
# 5615        reggae               all           all  6 weeks ago
#
#      Search Category                                        Release URL  \
# id
# 2                top  https://portrayalofguilt.bandcamp.com/album/po...
# 6                top  https://chatpile.bandcamp.com/album/portrayal-...
# 14               top  https://wednesdayband.bandcamp.com/album/twin-...
# 23               top     https://bedouine.bandcamp.com/album/waysides-2
# 25               top  https://linguaignota.bandcamp.com/album/sinner...
# ...              ...                                                ...
# 5576             new  https://mellodose.bandcamp.com/album/heaven-to-me
# 5583             new  https://headhunters.bandcamp.com/album/whos-go...
# 5599             new      https://hookshop.bandcamp.com/album/try-again
# 5606             new  https://nativesoulproject.bandcamp.com/album/t...
# 5615             new  https://chinamanyard.bandcamp.com/album/jailho...
#
#      Scrape Date                         Release Title  \
# id
# 2     2021-08-19  portrayal of guilt / Chat Pile Split
# 6     2021-08-19  portrayal of guilt / Chat Pile Split
# 14    2021-08-19                          Twin Plagues
# 23    2021-08-19                              Waysides
# 25    2021-08-19                      SINNER GET READY
# ...          ...                                   ...
# 5576  2021-08-20                          Heaven to Me
# 5583  2021-08-20                  whos going to volcom
# 5599  2021-08-20                             Try Again
# 5606  2021-08-20                           True Nature
# 5615  2021-08-20                     Jailhouse Skankin
#
#                                        Artist Name  \
# id
# 2                               portrayal of guilt
# 6                                        Chat Pile
# 14                                       Wednesday
# 23                                        Bedouine
# 25                                   LINGUA IGNOTA
# ...                                            ...
# 5576  Austin Grimm, Sun-Dried Vibes, and Mellodose
# 5583                                  Head Hunters
# 5599                                     hook shop
# 5606                           Native Soul Project
# 5615                   Stinging Ray & Roots Radics
#
#                    Artist Location Release Date  \
# id
# 2                    Austin, Texas   2021-08-17
# 6          Oklahoma City, Oklahoma   2021-08-17
# 14       Asheville, North Carolina   2021-08-13
# 23         Los Angeles, California   2021-10-15
# 25               Chicago, Illinois   2021-08-06
# ...                            ...          ...
# 5576              Adams, Tennessee   2021-06-25
# 5583  Huntington Beach, California   2021-07-18
# 5599                       Florida   2021-07-06
# 5606       Los Angeles, California   2021-06-30
# 5615                         China   2021-07-02
#
#                                                    Tags  \
# id
# 2     ['punk', 'black metal', 'hardcore', 'metal', '...
# 6     ['death metal', 'hardcore', 'industrial', 'met...
# 14    ['rock', 'country-gaze', 'indie', 'lo-fi', 'sh...
# 23    ['folk', 'indie folk', 'singer-songwriter', 'L...
# 25           ['experimental', 'retribution', 'Chicago']
# ...                                                 ...
# 5576  ['reggae', 'reggae rock', 'roots reggae', 'chi...
# 5583          ['headley', 'reggae', 'Huntington Beach']
# 5599  ['dancehall', 'dub', 'reggae', 'reggaepop', 'F...
# 5606  ['electronic', 'reggae', 'dub', 'electronic', ...
# 5615  ['reggae', 'roots', 'dancehall', 'one drop', '...
#
#                                              Track Info  \
# id
# 2     [{'Track Title': 'Touched by an Angel', 'Track...
# 6     [{'Track Title': 'portrayal of guilt - Touched...
# 14    [{'Track Title': 'Twin Plagues', 'Track Lyrics...
# 23    [{'Track Title': 'The Wave', 'Track Lyrics': '...
# 25    [{'Track Title': 'THE ORDER OF SPIRITUAL VIRGI...
# ...                                                 ...
# 5576  [{'Track Title': 'Heaven to Me', 'Track Lyrics...
# 5583  [{'Track Title': 'hoonter jam', 'Track Lyrics'...
# 5599  [{'Track Title': 'Try Again', 'Track Lyrics': ...
# 5606  [{'Track Title': 'One To Ten', 'Track Lyrics':...
# 5615  [{'Track Title': 'Jailhouse Skankin', 'Track L...
#
#                                              All Lyrics  Number of Tracks  \
# id
# 2     \nMy mind, tortured and depraved.\nDissolving....                 2
# 6     \nThe brutal truth is\nThat I’m just a simian ...                 2
# 14    \nYou are fearless\nYou defy death\nFlies are ...                12
# 23    \nWell of tomorrows\nFlow over for you\nNot re...                 1
# 25    \nHIDE YOUR CHILDREN HIDE YOUR HUSBAND  \nI AM...                 9
# ...                                                 ...               ...
# 5576  \nI just wanna be surrounded by trees\nMy frie...                 1
# 5583  \nKolton is a sex god beast man\nnot a black g...                 6
# 5599  \nTry Again\nI worry bout the sign of lies\nSh...                 1
# 5606  \nONE TO TEN\n\nOne for the land in the far ci...                 8
# 5615  \n«Mi say chatta box dont come fool me\nIt's a...                 2
#
#                                           Lyrics Tokens
# id
# 2     [My, mind,, tortured, and, depraved., Dissolvi...
# 6     [The, brutal, truth, is, That, I’m, just, a, s...
# 14    [You, are, fearless, You, defy, death, Flies, ...
# 23    [Well, of, tomorrows, Flow, over, for, you, No...
# 25    [HIDE, YOUR, CHILDREN, HIDE, YOUR, HUSBAND, I,...
# ...                                                 ...
# 5576  [I, just, wanna, be, surrounded, by, trees, My...
# 5583  [Kolton, is, a, sex, god, beast, man, not, a, ...
# 5599  [Try, Again, I, worry, bout, the, sign, of, li...
# 5606  [ONE, TO, TEN, One, for, the, land, in, the, f...
# 5615  [«Mi, say, chatta, box, dont, come, fool, me, ...
#
# [1118 rows x 16 columns]

# %%
scrape_df['Release Genre'].value_counts()#unique()
# Out:
# acoustic        172
# pop             168
# alternative     140
# rock            130
# r-b-soul         88
# country          88
# all              86
# hip-hop-rap      66
# blues            65
# experimental     45
# jazz             37
# reggae           33
# Name: Release Genre, dtype: int64

# %%
gen1 = 'alternative'
gen2 = 'rock'
gen3 = 'hip-hop-rap'

loc1 = 'Los Angeles'
loc2 = 'New York'
#loc3 = ''

# %%
comp1 = []
comp2 = []
comp3 = []
comp4 = []
comp5 = []

for index, row in scrape_df.iterrows():
    if gen1 in scrape_df.at[index,'Release Genre']:
        for w in scrape_df.at[index, 'Lyrics Tokens']:
            comp1.append(w)
    if gen2 in scrape_df.at[index,'Release Genre']:
        for w in scrape_df.at[index,'Lyrics Tokens']:
            comp2.append(w)
    if gen3 in scrape_df.at[index,'Release Genre']:
        for w in scrape_df.at[index,'Lyrics Tokens']:
            comp3.append(w)
    if gen3 in scrape_df.at[index,'Release Genre'] and loc1 in scrape_df.at[index,'Artist Location']:
        for w in scrape_df.at[index,'Lyrics Tokens']:
            comp4.append(w)
    if gen3 in scrape_df.at[index,'Release Genre'] and loc2 in scrape_df.at[index,'Artist Location']:
        for w in scrape_df.at[index,'Lyrics Tokens']:
            comp5.append(w)

all_stopwords = stopwords.words('english')
#go_list = ['and', 'And', 'But', 'but']
#all_stopwords=all_stopwords + go_list
#comp1=[contractions.fix(word) for word in comp1]
#comp2=[contractions.fix(word) for word in comp2]
#comp3=[contractions.fix(word) for word in comp3]

comp1_s = [word.lower().strip().replace('\xe2', "'").replace("’", "'") for word in comp1 if not word.lower() in all_stopwords]
comp2_s = [word.lower().strip().replace('\xe2', "'").replace("’", "'") for word in comp2 if not word.lower() in all_stopwords]
comp3_s = [word.lower().strip().replace('\xe2', "'").replace("’", "'") for word in comp3 if not word.lower() in all_stopwords]
comp4_s = [word.lower().strip().replace('\xe2', "'").replace("’", "'") for word in comp4 if not word.lower() in all_stopwords]
comp5_s = [word.lower().strip().replace('\xe2', "'").replace("’", "'") for word in comp5 if not word.lower() in all_stopwords]

# %%
import matplotlib.pyplot as plt

def random_color_func(word=None, font_size=None, position=None,  orientation=None, font_path=None, random_state=None):
    h = int(360.0 * 21.0 / 255.0)
    s = int(100.0 * 255.0 / 255.0)
    l = int(100.0 * float(random_state.randint(60, 120)) / 255.0)

    return "hsl({}, {}%, {}%)".format(h, s, l)


#wordcloud1 = WordCloud().generate(' '.join(comp1))

#plt.imshow(wordcloud1, interpolation='bilinear')
#plt.axis("off")

wordcloud1 = WordCloud(max_font_size=40, max_words=30, background_color='white', color_func=random_color_func ).generate(' '.join(comp1_s))
plt.figure(figsize=(10, 4))
plt.title("Genre: " + gen1)
plt.imshow(wordcloud1, interpolation='bilinear')
plt.axis("off")

plt.show()

# %%
#wordcloud2 = WordCloud().generate(' '.join(comp2))

#plt.imshow(wordcloud1, interpolation='bilinear')
#plt.axis("off")

wordcloud2 = WordCloud(max_font_size=40, max_words=30, background_color='white', color_func=random_color_func ).generate(' '.join(comp2_s))
plt.figure(figsize=(10, 4))
plt.title("Genre: " + gen2)
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")

plt.show()

# %%
wordcloud3 = WordCloud(max_font_size=40, max_words=30, background_color='white', color_func=random_color_func ).generate(' '.join(comp3_s))
plt.figure(figsize=(10, 4))
plt.title("Genre: " + gen3)
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis("off")

plt.show()

# %%
wordcloud4 = WordCloud(max_font_size=40, max_words=30, background_color='white', color_func=random_color_func ).generate(' '.join(comp4_s))
plt.figure(figsize=(10, 4))
plt.title("Genre: " + gen3 + ", Location: " + loc1)
plt.imshow(wordcloud4, interpolation='bilinear')
plt.axis("off")

plt.show()

# %%
wordcloud5 = WordCloud(max_font_size=40, max_words=30, background_color='white', color_func=random_color_func ).generate(' '.join(comp5_s))
plt.figure(figsize=(10, 4))
plt.title("Genre: " + gen3 + ", Location: " + loc2)
plt.imshow(wordcloud5, interpolation='bilinear')
plt.axis("off")

plt.show()

# %%
import collections

counter = collections.Counter(comp5_s)

top_ten = counter.most_common(30)

top_ten_index = []
top_ten_value = []

for index, value in top_ten:
    top_ten_index.append(index)
    top_ten_value.append(value)
print(top_ten_index)
plt.figure(figsize=(25,10))

plt.bar(top_ten_index,top_ten_value);
# Out:
# ['got', "i'm", 'like', 'get', 'ya', "ain't", 'make', '-', 'money', '/', 'gotta', 'nigga', 'it,', 'know', "can't", 'pull', 'em', 'niggas', 'never', 'time', "i'll", "that's", 'see', "it's", 'shit', 'say', 'back', 'call', 'take', 'keep']
